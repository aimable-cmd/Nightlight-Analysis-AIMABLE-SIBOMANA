# %% [markdown]
# # Generating Zonal Statistics with a Custom Script
# This notebook demonstrates how to generate zonal statistics using a custom Python script, with a focus on analyzing night light intensity across administrative regions in Rwanda. You will learn how to set up your workspace, import and prepare geospatial data, clip global raster datasets to a country boundary, and visualize the results. The workflow includes using custom utilities for zonal statistics, merging results with administrative boundaries, and saving the outputs for further analysis. This hands-on approach provides practical experience with geospatial data processing, raster analysis, and the integration of Python geospatial libraries such as geopandas and rasterio.
#
# **Zonal statistics** are summary statistics (such as mean, sum, median, minimum, or maximum) calculated for values of a raster dataset within the boundaries of defined zones, such as polygons representing administrative regions or land cover types.

# %% [markdown]
# ## Setup and Imports

# %%
from osgeo import gdal

# %%
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import rasterio

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.6.3

# %% [markdown]
# ### Required Packages

# %%
# Some packages like GeoPandas, Rasterio, Numpy, Matplotlib, 
# their versions are differ from the suggested ones due to compatobility issues.

from osgeo import gdal
import geopandas, rasterio, pandas, numpy, matplotlib, seaborn, jupyter
print("All packages imported successfully!")
print(f"GDAL version: {gdal.__version__}")
print(f"GeoPandas version: {geopandas.__version__}")
print(f"Rasterio version: {rasterio.__version__}")
print(f"Pandas version: {pandas.__version__}")
print(f"Numpy version: {numpy.__version__}")
print(f"Matplotlib version: {matplotlib.__version__}")
print(f"Seaborn version: {seaborn.__version__}")
print(f"Jupyter version: {jupyter.__version__}")
# Out:
# All packages imported successfully!
# GDAL version: 3.6.2
# GeoPandas version: 0.13.2
# Rasterio version: 1.3.9
# Pandas version: 1.5.3
# Numpy version: 1.25.2
# Matplotlib version: 3.6.3
# Seaborn version: 0.12.2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 14
#      12 print(f"Matplotlib version: {matplotlib.__version__}")
#      13 print(f"Seaborn version: {seaborn.__version__}")
# ---> 14 print(f"Jupyter version: {jupyter.__version__}")
#
# AttributeError: module 'jupyter' has no attribute '__version__'

# %%
import notebook
import jupyter_core
import jupyter_client

print(f"notebook version: {notebook.__version__}")
print(f"jupyter_core version: {jupyter_core.__version__}")
print(f"jupyter_client version: {jupyter_client.__version__}")
# Out:
# notebook version: 7.4.7
# jupyter_core version: 5.9.1
# jupyter_client version: 8.6.3

# %%
# %pip install --upgrade numpy pandas geopandas rasterio fiona matplotlib seaborn

import sys
from pathlib import Path
import os
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
#import seaborn as sns
import rasterio
from rasterio.mask import mask
from rasterio.warp import calculate_default_transform, reproject, Resampling
import warnings
import fiona
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: numpy in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (2.3.4)
# Requirement already satisfied: pandas in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: geopandas in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (1.1.1)
# Requirement already satisfied: rasterio in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (1.4.3)
# Collecting fiona
#   Using cached fiona-1.10.1-cp311-cp311-win_amd64.whl (24.5 MB)
# Requirement already satisfied: matplotlib in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (3.10.7)
# Requirement already satisfied: seaborn in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: affine in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from rasterio) (2025.10.5)
# Requirement already satisfied: click>=4.0 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from rasterio) (8.3.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from rasterio) (3.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: colorama in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\documents\github\assignment 3\nightlight-analysis-aimable-sibomana\nightlight-analysis\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: fiona
# Successfully installed fiona-1.10.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy; print(numpy.__version__)
import pandas; print(pandas.__version__)
import geopandas; print(geopandas.__version__)
import matplotlib; print(matplotlib.__version__)
import seaborn; print(seaborn.__version__)
import rasterio; print(rasterio.__version__)
# Out:
# 2.3.4
# 2.3.3
# 1.1.1
# 3.10.7
# 0.13.2
# 1.4.3

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Workspace Directory Setup

# %%
from pathlib import Path

# %%
# Current working directory
cwd = Path.cwd()
print("Current working directory:", cwd)

# Parent directory of the working directory
parent = cwd.parent
print("Parent directory:", parent)
# Out:
# Current working directory: c:\Users\user\Documents\GitHub\Assignment 3\Nightlight-Analysis-AIMABLE-SIBOMANA\notebooks
# Parent directory: c:\Users\user\Documents\GitHub\Assignment 3\Nightlight-Analysis-AIMABLE-SIBOMANA

# %%
DIR_WORKSPACE = Path.cwd()
DIR_DATA = DIR_WORKSPACE / "data"
DIR_SRC = DIR_WORKSPACE / "src"

# %% [markdown]
# ### Import Custom Python Script

# %%
import sys

# %%
# Add src directory to path to import our custom script
sys.path.append(str(DIR_SRC))

# %%
import spatial_utils

# %% [markdown]
# ### Input Data Files
# For the night lights file, please make sure you unzip it first.

# %%
# ==========================================
# FILE PATHS
# ===========================================

# Unzipped night lights raster file with "tif" extension
FILE_NTL = DIR_DATA / "C:/Users/user/Documents/GitHub/Assignment 3/VNL_npp_2024_global_vcmslcfg_v2_c202502261200.average_masked.dat (5).tif/VNL_npp_2024_global_vcmslcfg_v2_c202502261200.average_masked.dat.tif"

# Shapefile with cell level (admin region level 4) boundaries 
FILE_SHP_ADM4 = DIR_DATA / "C:/Users/user/Documents/GitHub/Assignment 3/pop-demo-infra-20251019T084236Z-1-001/pop-demo-infra/adm4-pop-buildings.shp"

# Shapefile with national boundaries (admin region level 0)
FILE_SHP_ADM0 = DIR_DATA / "C:/Users/user/Documents/GitHub/Assignment 3/geoBoundaries-RWA-ADM0-all-20251019T084125Z-1-001/geoBoundaries-RWA-ADM0-all/geoBoundaries-RWA-ADM0.shp"

# %% [markdown]
# ## Zonal Statistics Analysis

# %% [markdown]
# ### Clip Global Raster to Rwanda
# To make the raster file smaller and more manageable, we will clip (cut) it to the boundary of Rwanda. This step extracts only the portion of the raster that falls within Rwanda’s borders, reducing file size and improving processing efficiency.

# %%
def clip_raster_to_boundary(input_raster_path, boundary_gdf, output_path):
    """
    Clip a global raster to a country boundary
    
    Parameters:
    -----------
    input_raster_path : str
        Path to input raster file
    boundary_gdf : geopandas.GeoDataFrame
        Boundary for clipping
    output_path : str
        Path for output clipped raster
    
    Returns:
    --------
    str : Path to clipped raster
    """
    print(f"Clipping global raster to Rwanda boundary...")
    
    with rasterio.open(input_raster_path) as src:
        print(f"Original raster info:")
        print(f"  - Shape: {src.width} x {src.height}")
        print(f"  - CRS: {src.crs}")
        print(f"  - Bounds: {src.bounds}")
        print(f"  - Resolution: {src.res}")
        
        # Reproject boundary to match raster CRS if needed
        if boundary_gdf.crs != src.crs:
            print(f"Reprojecting boundary from {boundary_gdf.crs} to {src.crs}")
            boundary_gdf = boundary_gdf.to_crs(src.crs)
        
        # Clip raster
        clipped_data, clipped_transform = mask(
            src, 
            boundary_gdf.geometry, 
            crop=True,
            nodata=src.nodata
        )
        
        # Update metadata
        clipped_meta = src.meta.copy()
        clipped_meta.update({
            "driver": "GTiff",
            "height": clipped_data.shape[1],
            "width": clipped_data.shape[2],
            "transform": clipped_transform
        })
        
        # Create output directory if needed
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        
        # Write clipped raster
        with rasterio.open(output_path, "w", **clipped_meta) as dest:
            dest.write(clipped_data)
        
        print(f"✓ Clipped raster saved to: {output_path}")
        print(f"Clipped raster info:")
        print(f"  - Shape: {clipped_data.shape[2]} x {clipped_data.shape[1]}")
        print(f"  - Data range: {np.nanmin(clipped_data)} to {np.nanmax(clipped_data)}")
        
    return output_path

# %% [markdown]
# corrected version

# %% [markdown]
# ### Visualize Clipped Raster

# %%
import os
from pathlib import Path

import numpy as np
import geopandas as gpd
import rasterio
from rasterio.mask import mask
from shapely.geometry import mapping
from shapely.ops import unary_union

def clip_raster_to_boundary(input_raster_path, boundary_gdf, output_path):
    """
    Clip a raster to a boundary (GeoDataFrame polygons).

    Parameters
    ----------
    input_raster_path : str | Path
        Path to input raster file.
    boundary_gdf : geopandas.GeoDataFrame
        Polygon boundary/boundaries to clip to.
    output_path : str | Path
        Path for output clipped raster (GeoTIFF).

    Returns
    -------
    str
        Path to clipped raster.
    """
    input_raster_path = Path(input_raster_path)
    output_path = Path(output_path)

    print("Clipping raster to boundary…")
    with rasterio.open(input_raster_path) as src:
        print("Original raster info:")
        print(f"  - Size: {src.width} x {src.height} (W x H)")
        print(f"  - Bands: {src.count}")
        print(f"  - CRS: {src.crs}")
        print(f"  - Bounds: {src.bounds}")
        print(f"  - Resolution: {src.res}")
        print(f"  - Dtype: {src.dtypes[0]}")
        print(f"  - NODATA: {src.nodata}")

        # 1) Ensure boundary GeoDataFrame is valid & same CRS
        if boundary_gdf.crs != src.crs:
            print(f"Reprojecting boundary from {boundary_gdf.crs} → {src.crs}")
            boundary_gdf = boundary_gdf.to_crs(src.crs)

        # Drop empties / fix invalids
        boundary = boundary_gdf.geometry
        boundary = boundary[boundary.notna() & (~boundary.is_empty)]
        if len(boundary) == 0:
            raise ValueError("Boundary has no valid geometries after cleaning.")

        # Dissolve to one geometry to avoid tiny slivers/holes
        dissolved = unary_union(boundary)
        # Some invalids get fixed by a zero-width buffer
        if not dissolved.is_valid:
            dissolved = dissolved.buffer(0)

        shapes = [mapping(dissolved)]  # GeoJSON-like for rasterio.mask

        # 2) Clip
        clipped_data, clipped_transform = mask(
            src,
            shapes,
            crop=True,
            nodata=src.nodata,   # preserve nodata if set
            filled=True          # fill outside with nodata
        )

        # 3) Prepare output metadata
        meta = src.meta.copy()
        meta.update({
            "driver": "GTiff",
            "height": clipped_data.shape[1],
            "width":  clipped_data.shape[2],
            "transform": clipped_transform,
            "compress": "deflate",
            "tiled": True,
            "bigtiff": "IF_SAFER",
        })
        # Ensure CRS & nodata kept
        if src.crs is not None:
            meta["crs"] = src.crs
        # If nodata is missing but dtype is integer, choose a nodata value
        if meta.get("nodata", None) is None:
            if np.issubdtype(np.dtype(meta["dtype"]), np.integer):
                meta["nodata"] = 0  # pick a reasonable integer nodata
            else:
                # For float rasters, nodata can be NaN; rasterio stores it as None in metadata.
                pass

    # 4) Write output
    output_path.parent.mkdir(parents=True, exist_ok=True)
    with rasterio.open(output_path, "w", **meta) as dest:
        dest.write(clipped_data)

    # 5) Stats (ignore nodata safely)
    nodata_val = meta.get("nodata", None)
    data_for_stats = clipped_data.astype("float64", copy=False)
    if nodata_val is not None:
        data_for_stats = np.where(data_for_stats == nodata_val, np.nan, data_for_stats)

    finite = np.isfinite(data_for_stats)
    if finite.any():
        vmin = float(np.nanmin(data_for_stats[finite]))
        vmax = float(np.nanmax(data_for_stats[finite]))
    else:
        vmin = vmax = float("nan")

    print(f"✓ Clipped raster saved to: {output_path}")
    print("Clipped raster info:")
    print(f"  - Size: {meta['width']} x {meta['height']} (W x H)")
    print(f"  - Bands: {meta['count']}")
    print(f"  - CRS: {meta.get('crs')}")
    print(f"  - NODATA: {meta.get('nodata')}")
    print(f"  - Data range (excl. nodata): {vmin} … {vmax}")

    return str(output_path)

# %%
pip install matplotlib==3.6.3
# Out:
# Requirement already satisfied: matplotlib==3.6.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.6.3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.6.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.6.3) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.6.3) (1.4.9)
# Requirement already satisfied: numpy>=1.19 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.6.3) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib==3.6.3) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.6.3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from matplotlib==3.6.3) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from matplotlib==3.6.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib==3.6.3) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
FILE_SHP_ADM4 = "C:\\Users\\user\\Documents\\GitHub\\Assignment 3\\pop-demo-infra-20251019T084236Z-1-001\\pop-demo-infra\\adm4-pop-buildings.shp"

# %%
gdf_adm4 = gpd.read_file(FILE_SHP_ADM4, engine="pyogrio")

# %%
import geopandas as gpd

# %%
import geopandas as gpd
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# %%
import rasterio
from rasterio.enums import Resampling

# Adjust this factor to find the balance between quality and memory use
DOWNSAMPLE_FACTOR = 10

with rasterio.open(r"C:/Users/user/Documents/GitHub/Assignment 3/VNL.tif/rwanda_nightlights.tif.tif") as src:
    # Read a smaller version of the raster
    data = src.read(
        1,
        out_shape=(
            1,
            src.height // DOWNSAMPLE_FACTOR,
            src.width // DOWNSAMPLE_FACTOR
        ),
        resampling=Resampling.average
    )

    # Compute new transform
    transform = src.transform * src.transform.scale(
        (src.width / data.shape[-1]),
        (src.height / data.shape[-2])
    )

    extent = [
        transform[2],
        transform[2] + transform[0] * data.shape[1],
        transform[5] + transform[4] * data.shape[0],
        transform[5]
    ]

# %%
# Visualize the downsampled raster _ Displayed error due to large data size.
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.imshow(data, extent=extent, cmap='viridis')
plt.title("Downsampled Nightlight Raster")
plt.colorbar(label='Intensity')
plt.show()

# %%
data = data.astype("float32")  # or use "uint8" if you're scaling to 0–255

# %%
# Use aggressive downsampling + masked plotting to reduce memory use
import rasterio
from rasterio.enums import Resampling
import matplotlib.pyplot as plt
import numpy as np

def plot_downsampled_raster(path, factor=20):
    with rasterio.open(r"C:/Users/user/Documents/GitHub/Assignment 3/VNL.tif/rwanda_nightlights.tif.tif") as src:
        data = src.read(
            1,
            out_shape=(
                1,
                src.height // factor,
                src.width // factor
            ),
            resampling=Resampling.average
        ).astype("float32")  # Reduce memory use

        # Clean up NaNs or nodata values
        data = np.ma.masked_equal(data, src.nodata if src.nodata is not None else 0)

        # Compute extent
        transform = src.transform * src.transform.scale(
            (src.width / data.shape[-1]),
            (src.height / data.shape[-2])
        )
        extent = [
            transform[2],
            transform[2] + transform[0] * data.shape[1],
            transform[5] + transform[4] * data.shape[0],
            transform[5]
        ]

    # Plot
    plt.figure(figsize=(10, 6))
    plt.imshow(data, extent=extent, cmap="viridis")
    plt.colorbar(label="Intensity")
    plt.title("Downsampled Raster")
    plt.tight_layout()
    plt.savefig("downsampled_raster.png", dpi=150)
    plt.close()
    print("✅ Saved to: downsampled_raster.png")

# %%
# Then call it with:
plot_downsampled_raster("your_raster_path.tif", factor=20)
# Out:
# ✅ Saved to: downsampled_raster.png

# %%
# Open the saved image with:
from PIL import Image
Image.open("downsampled_raster.png").show()

# %% [markdown]
# ### Generate Cell Level Zonal Statistics

# %%
from pathlib import Path

raster_path = Path(r"C:/Users/user/Documents/GitHub/Assignment 3/VNL.tif/rwanda_nightlights.tif.tif")
print(raster_path)
# Out:
# C:\Users\user\Documents\GitHub\Assignment 3\VNL.tif\rwanda_nightlights.tif.tif

# %%
from pathlib import Path

rwanda_raster_path = Path(r"C:/Users/user/Documents/GitHub/Assignment 3/VNL.tif/rwanda_nightlights.tif.tif")

# %%
import os

file_path = (r"C:/Users/user/Documents/GitHub/Assignment 3/VNL.tif/rwanda_nightlights.tif.tif")
print(os.path.exists(file_path))
# Out:
# True

# %%
# ===================================================
# GENERATING ZONAL STATISTICS WITH A CUSTOM SCRIPT
# ===================================================

# Create ZonalStatistics object using the clipped Rwanda data with
# the following args
# 1. Path of clipped night lights raster/image: rwanda_raster_path
# 2. Path of administrative boundaries shapefile: FILE_SHP_ADM4
# 3. Administrative level: 4

from rasterstats import zonal_stats
import geopandas as gpd
import rasterio

DIR_WORKSPACE = Path.cwd()
DIR_DATA = DIR_WORKSPACE / "data"
DIR_SRC = DIR_WORKSPACE / "src"

FILE_SHP_ADM4 = DIR_DATA / (r"C:/Users/user/Documents/GitHub/Assignment 3/pop-demo-infra-20251019T084236Z-1-001/pop-demo-infra/adm4-pop-buildings.shp")
FILE_RASTER = DIR_DATA / (r"C:/Users/user/Documents/GitHub/Assignment 3/VNL.tif/rwanda_nightlights.tif.tif")


admin_level = "cell_id"


#with rasterio.open(FILE_RASTER) as src:
#zs = zonal_stats(FILE_RASTER, FILE_SHP_ADM4, admin_level)


# 1. Load admin boundaries
gdf_adm4 = gpd.read_file(FILE_SHP_ADM4, engine="pyogrio")

# 2. Run zonal statistics
#    stats = ["mean", "sum", "min", "max", "median", "std"] → adjust as needed
zs = zonal_stats(
    vectors=gdf_adm4,               # use loaded GeoDataFrame
    raster=str(rwanda_raster_path), # use clipped raster path as string
    stats=["mean", "sum", "min", "max", "median"], 
    geojson_out=True                # return GeoJSON features with geometry
)

# 3. Convert back into a GeoDataFrame
gdf_stats = gpd.GeoDataFrame.from_features(zs, crs=gdf_adm4.crs)

# 4. Inspect
print(gdf_stats.head())
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\rasterstats\io.py:335: NodataWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn(
#                                             geometry        cell_id  \
# 0  POLYGON ((29.97630 -1.51480, 29.97330 -1.51440...  RWA.1.1.1.1_1
# 1  POLYGON ((29.96730 -1.48260, 29.96160 -1.48070...  RWA.1.1.1.2_1
# 2  POLYGON ((29.96100 -1.47140, 29.96290 -1.47340...  RWA.1.1.1.3_1
# 3  POLYGON ((29.97130 -1.51330, 29.98110 -1.51650...  RWA.1.1.1.4_1
# 4  POLYGON ((29.83940 -1.39180, 29.83870 -1.39370...  RWA.1.1.2.1_1
#
#      province_n district_n sector_nam cell_name  elderly_60   general_20  \
# 0  Amajyaruguru     Burera     Bungwe    Bungwe  241.693282  3855.623385
# 1  Amajyaruguru     Burera     Bungwe  Bushenya  229.611624  3669.128833
# 2  Amajyaruguru     Burera     Bungwe  Mudugari  109.718616  1756.630395
# 3  Amajyaruguru     Burera     Bungwe     Tumba  318.065743  5174.177333
# 4  Amajyaruguru     Burera     Butaro   Gatsibo  335.976866  6046.478580
#
#    children_u   youth_15_2     men_2020   women_2020  building_c  min  \
# 0  495.422606   758.093936  1850.711053  2004.912332      1435.0  0.0
# 1  470.655098   720.896415  1761.457437  1907.671396       884.0  0.0
# 2  225.188715   345.073314   843.263769   913.366626       530.0  0.0
# 3  666.434701  1016.066328  2482.353880  2691.823510      1512.0  0.0
# 4  833.994018  1264.716616  2880.475354  3166.003226      2036.0  0.0
#
#         max      mean       sum  median
# 0  0.000000  0.000000  0.000000     0.0
# 1  0.000000  0.000000  0.000000     0.0
# 2  0.000000  0.000000  0.000000     0.0
# 3  0.000000  0.000000  0.000000     0.0
# 4  0.972752  0.028464  1.935569     0.0

# %%
# There is no load_data() method for the zs list, so this line should be removed.
# If you want to inspect the zonal statistics, you can print or display the first few entries:
print("First zonal statistics feature:")
print(zs[0])
# Out:
# First zonal statistics feature:
# {'id': '0', 'type': 'Feature', 'properties': {'cell_id': 'RWA.1.1.1.1_1', 'province_n': 'Amajyaruguru', 'district_n': 'Burera', 'sector_nam': 'Bungwe', 'cell_name': 'Bungwe', 'elderly_60': 241.69328199999998, 'general_20': 3855.623385, 'children_u': 495.422606, 'youth_15_2': 758.093936, 'men_2020': 1850.711053, 'women_2020': 2004.9123319999999, 'building_c': 1435.0, 'min': 0.0, 'max': 0.0, 'mean': 0.0, 'sum': 0.0, 'median': 0.0}, 'geometry': {'type': 'Polygon', 'coordinates': (((29.9763, -1.5148), (29.9733, -1.5144), (29.9691, -1.5109), (29.9713, -1.502), (29.9674, -1.495), (29.9623, -1.4919), (29.9612, -1.4833), (29.962, -1.4808), (29.966, -1.4828), (29.9702, -1.4824), (29.98, -1.4765), (29.9834, -1.4861), (29.9781, -1.4885), (29.9756, -1.4916), (29.9807, -1.5015), (29.9833, -1.5014), (29.9834, -1.5039), (29.9805, -1.5089), (29.9817, -1.5161), (29.9763, -1.5148)),)}, 'bbox': (29.9612, -1.5161, 29.9834, -1.4765)}

# %%
# =======================================
# DEFINE WHICH STATISTICS TO CALCULATE
# =======================================
stats_to_calculate = ['mean', 'median', 'count', "sum"]

print(f"Calculating statistics: {stats_to_calculate}")
print("This may take a few minutes depending on data size...")

# The zonal statistics have already been calculated and stored in gdf_stats
df_stats = gdf_stats.copy()

# Display results
print(f"\nAnalysis complete! Results shape: {df_stats.shape}")
display(df_stats.head(10))
# Out:
# Calculating statistics: ['mean', 'median', 'count', 'sum']
# This may take a few minutes depending on data size...
#
# 9  0.000000  0.000000   0.000000  0.00000

# %%
print(df_stats.columns.tolist())
# Out:
# ['geometry', 'cell_id', 'province_n', 'district_n', 'sector_nam', 'cell_name', 'elderly_60', 'general_20', 'children_u', 'youth_15_2', 'men_2020', 'women_2020', 'building_c', 'min', 'max', 'mean', 'sum', 'median']

# %%
print(gdf_adm4.columns.tolist())
# Out:
# ['cell_id', 'province_n', 'district_n', 'sector_nam', 'cell_name', 'elderly_60', 'general_20', 'children_u', 'youth_15_2', 'men_2020', 'women_2020', 'building_c', 'geometry']

# %%
# Make sure the output directory exists
(DIR_DATA / "ntl").mkdir(parents=True, exist_ok=True)

# %%
import geopandas as gpd
import rasterio
import rasterstats

# Example
df_out = rasterstats.zonal_stats (r"C:/Users/user/Documents/GitHub/Assignment 3/pop-demo-infra-20251019T084236Z-1-001/pop-demo-infra/adm4-pop-buildings.shp", r"C:/Users/user/Documents/GitHub/Assignment 3/VNL.tif/rwanda_nightlights.tif.tif", geojson_out=True)

# %%
# ==================================================
# SAVE RESULTS
# ==================================================

# Merge using 'cell_id' as the key, not 'geometry'
cols2keep = ['cell_id', 'province_n', 'district_n', 'sector_nam', 'cell_name']
df_stats2 = df_stats.merge(gdf_adm4[cols2keep], on='cell_id', how='left')

# After merge, columns have suffixes (_x, _y). Use the correct ones.
# The statistics columns are: 'mean', 'median', 'sum'
# There is no 'count' column, so we drop it from cols2save.

cols2save_actual = ['province_n_x', 'district_n_x', 'sector_nam_x', 'cell_name_x', 'mean', 'median', 'sum']

# Optionally, rename columns for output
df_out = df_stats2[cols2save_actual].rename(columns={
    'province_n_x': 'province_n',
    'district_n_x': 'district_n',
    'sector_nam_x': 'sector_nam',
    'cell_name_x': 'cell_name'
})

df_out.to_csv(DIR_DATA / "ntl/rw-adm4-ntl-stats.csv", index=False)
print("Saved zonal statistics to:", DIR_DATA / "ntl/rw-adm4-ntl-stats.csv")
# Out:
# Saved zonal statistics to: c:\Users\user\Documents\GitHub\Assignment 3\Nightlight-Analysis-AIMABLE-SIBOMANA\notebooks\data\ntl\rw-adm4-ntl-stats.csv

# %%
## Report on Cells with Largest Night Light Values
largest_cells = df_stats2.nlargest(10, 'mean')
print("Cells with the largest night light values:")
display(largest_cells)
# Out:
# Cells with the largest night light values:
#                                                geometry         cell_id  \
# 2066  POLYGON ((30.12370 -1.95800, 30.12460 -1.95660...  RWA.5.1.13.4_1
# 2042  POLYGON ((30.08840 -1.96290, 30.08460 -1.95770...   RWA.5.1.8.3_1
# 2147  POLYGON ((30.06250 -1.93880, 30.06450 -1.94070...   RWA.5.3.6.2_1
# 2163  POLYGON ((30.06750 -1.96690, 30.06540 -1.96350...   RWA.5.3.9.3_1
# 2040  POLYGON ((30.09300 -1.94900, 30.09550 -1.94900...   RWA.5.1.8.1_1
# 2161  POLYGON ((30.06700 -1.97050, 30.06360 -1.97160...   RWA.5.3.9.1_1
# 2152  POLYGON ((30.07430 -1.94560, 30.07690 -1.95480...   RWA.5.3.6.7_1
# 2150  POLYGON ((30.07140 -1.94620, 30.07140 -1.94750...   RWA.5.3.6.5_1
